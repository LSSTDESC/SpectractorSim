# %% [markdown]
# # View Telescope Transmission

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import sys
import os

# %%
sys.path.append("../../spectractorsim")
sys.path.append("../../spectractor")

# %%
import libCTIOTransm as ctio
import spectractorsim as sim

# %%
tel=sim.TelescopeTransmission()

# %%
tel.plot_transmission(scale='log')
# Out:
# ../../spectractorsim/spectractorsim.py:453: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(WL,2.5*np.log10(self.qe(WL)),'b-',label='qe')
# ../../spectractorsim/spectractorsim.py:457: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(WL,2.5*np.log10(self.tfr(WL)),'k:',label='RG715')
# ../../spectractorsim/spectractorsim.py:458: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(WL,2.5*np.log10(self.tfb(WL)),'k--',label='FGB37')
# ../../spectractorsim/spectractorsim.py:459: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(WL,2.5*np.log10(self.transmission(WL)),'r-',lw=2,label='tot')
